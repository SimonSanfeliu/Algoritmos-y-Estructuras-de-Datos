# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonSanfeliu/Algoritmos-y-Estructuras-de-Datos/blob/master/archivos_para_algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b71c292b-7c10-4132-8ba3-19ff27dfb7eb" name="files[]" multiple disabled />
#      <output id="result-b71c292b-7c10-4132-8ba3-19ff27dfb7eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Diapositiva1.PNG to Diapositiva1.PNG
# Saving Diapositiva2.PNG to Diapositiva2.PNG
# Saving Diapositiva3.PNG to Diapositiva3.PNG
# Saving Diapositiva4.PNG to Diapositiva4.PNG
# Saving Diapositiva5.PNG to Diapositiva5.PNG
# ...
